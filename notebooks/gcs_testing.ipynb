# %%
from google.cloud import storage
client = storage.Client()
for bucket in client.list_buckets():
    print(bucket.name)
# Out:
# audio-filler-1
# dataflow-staging-us-central1-849641412420
# hw-5-de
